# %% [markdown]
# # Luma AI Event Scout
# By [Alex Fazio](https://x.com/alxfazio/)
# Github repo: [social-crawler](https://github.com/alexfazio/social-crawler)
#
# This Jupyter notebook demonstrates an automated pipeline for discovering AI-related events from Luma using Firecrawl's advanced web scraping capabilities. The workflow enables you to:
#
# - Dynamically select cities from a global list using Firecrawl's URL construction
# - Scrape event listings from Luma's city-specific pages
# - Extract structured event data using Firecrawl's LLM-powered extraction
# - Implement semantic filtering with OpenAI to identify AI-focused events
# - Automate Discord notifications for high-confidence matches
#
# This solution is particularly valuable for community builders and tech enthusiasts who want to track emerging AI meetups, workshops, and conferences across 60+ global cities.
#
# **Key Firecrawl Uses:**
# - City-specific URL scraping with CSS selector targeting
# - Structured extraction of event details using Pydantic models
# - Schema validation for consistent event data formatting
# - Batch processing of multiple event URLs
#
# **Practical Application:**
# Automatically monitor Luma event platforms across major tech hubs worldwide, filter for AI-related gatherings using semantic analysis, and receive instant Discord alerts for high-quality matches.
#
# Requirements
# Before proceeding, ensure you have:
# - Firecrawl API key (for city-based scraping and extraction)
# - OpenAI API key (for AI content filtering)
# - Discord webhook URL (for real-time notifications)
#
# We leverage these core packages:
# - firecrawl-py: For location-based event discovery and structured data extraction
# - openai: For semantic analysis of event descriptions
# - requests: For Discord integration and notification delivery

# %% [markdown]
# ## Input API Keys

# %%
from getpass import getpass
openai_api_key = getpass("Enter your OpenAI API key: ")
firecrawl_api_key = getpass("Enter your Firecrawl API key: ")
DISCORD_WEBHOOK_URL = getpass("Enter your Discord WEbhook URL: ")

# %% [markdown]
# # Firecrawl Scrape

# %% [markdown]
# ## Install Dependencies

# %%
# %pip install requests python-dotenv openai firecrawl-py -q
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports

# %%
import os
import requests
import json
import pprint
from firecrawl import FirecrawlApp

# %% [markdown]
# ## Define City of Interest

# %%
# Define City of Interest

## Define City of Interest
# Define city mapping
cities = {
    1: 'atlanta',
    2: 'austin',
    3: 'bogota',
    4: 'boston',
    5: 'buenos-aires',
    6: 'chicago',
    7: 'dallas',
    8: 'denver',
    9: 'houston',
    10: 'los-angeles',
    11: 'mexico-city',
    12: 'miami',
    13: 'montreal',
    14: 'nyc',
    15: 'philadelphia',
    16: 'phoenix',
    17: 'portland',
    18: 'salt-lake-city',
    19: 'san-diego',
    20: 'sf',
    21: 'sao-paulo',
    22: 'seattle',
    23: 'toronto',
    24: 'vancouver',
    25: 'washington-dc',
    26: 'waterloo',
    27: 'lagos',
    28: 'nairobi',
    29: 'bangkok',
    30: 'bengaluru',
    31: 'dubai',
    32: 'ho-chi-minh-city',
    33: 'hong-kong',
    34: 'jakarta',
    35: 'kuala-lumpur',
    36: 'manila',
    37: 'melbourne',
    38: 'mumbai',
    39: 'new-delhi',
    40: 'seoul',
    41: 'singapore',
    42: 'sydney',
    43: 'taipei',
    44: 'tel-aviv',
    45: 'tokyo',
    46: 'amsterdam',
    47: 'barcelona',
    48: 'berlin',
    49: 'brussels',
    50: 'copenhagen',
    51: 'helsinki',
    52: 'istanbul',
    53: 'lisbon',
    54: 'london',
    55: 'madrid',
    56: 'milan',
    57: 'munich',
    58: 'paris',
    59: 'stockholm',
    60: 'zurich'
}

# Display city selection
print("Select a city to scrape:")
for num, name in cities.items():
    print(f"{num}. {name.replace('-', ' ').title()}")

# Get valid user input
while True:
    try:
        selection = int(input("\nEnter city number (1-60): "))
        if 1 <= selection <= 60:
            city = cities[selection]
            break
        else:
            print("Please enter a number between 1 and 60")
    except ValueError:
        print("Invalid input. Please enter a number.")

print(f"\nSelected city: {city.replace('-', ' ').title()}")
# Out:
# Select a city to scrape:
# 1. Atlanta
# 2. Austin
# 3. Bogota
# 4. Boston
# 5. Buenos Aires
# 6. Chicago
# 7. Dallas
# 8. Denver
# 9. Houston
# 10. Los Angeles
# 11. Mexico City
# 12. Miami
# 13. Montreal
# 14. Nyc
# 15. Philadelphia
# 16. Phoenix
# 17. Portland
# 18. Salt Lake City
# 19. San Diego
# 20. Sf
# 21. Sao Paulo
# 22. Seattle
# 23. Toronto
# 24. Vancouver
# 25. Washington Dc
# 26. Waterloo
# 27. Lagos
# 28. Nairobi
# 29. Bangkok
# 30. Bengaluru
# 31. Dubai
# 32. Ho Chi Minh City
# 33. Hong Kong
# 34. Jakarta
# 35. Kuala Lumpur
# 36. Manila
# 37. Melbourne
# 38. Mumbai
# 39. New Delhi
# 40. Seoul
# 41. Singapore
# 42. Sydney
# 43. Taipei
# 44. Tel Aviv
# 45. Tokyo
# 46. Amsterdam
# 47. Barcelona
# 48. Berlin
# 49. Brussels
# 50. Copenhagen
# 51. Helsinki
# 52. Istanbul
# 53. Lisbon
# 54. London
# 55. Madrid
# 56. Milan
# 57. Munich
# 58. Paris
# 59. Stockholm
# 60. Zurich
#
# Selected city: Sf

# %% [markdown]
# ## Instantiate FirecrawlApp

# %%
# Initialize Firecrawl client
app = FirecrawlApp(api_key=firecrawl_api_key)

# %% [markdown]
# ## Firecrawl Scrape

# %%
## Firecrawl Scrape

# Verify city selection exists
if 'city' not in locals():
    raise ValueError("City not selected - please run the city selection cell first")

# Scrape event links for selected city
response = app.scrape_url(
    url=f'https://lu.ma/{city}',
    params={
        'formats': ['links'],
        'includeTags': ['.event-link.content-link']
    }
)

# Extract and validate links
links_list = response.get('links', [])
if not links_list:
    print(f"No events found for {city.replace('-', ' ').title()}")
else:
    print(f"Found {len(links_list)} events in {city.replace('-', ' ').title()}:")
    pprint.pprint(links_list)
# Out:
# Found 20 events in Sf:
# ['https://lu.ma/aidevfeb',
#  'https://lu.ma/z9blbdti',
#  'https://lu.ma/sfdata',
#  'https://lu.ma/thoughtexperiments',
#  'https://lu.ma/5ycmcpa8',
#  'https://lu.ma/0zo4ebka',
#  'https://lu.ma/6pk5espk',
#  'https://lu.ma/trends2025',
#  'https://lu.ma/vgss0zqv',
#  'https://lu.ma/LSEevent',
#  'https://lu.ma/kf9v1pd9',
#  'https://lu.ma/rxpzx3gt',
#  'https://lu.ma/thfrtcq7',
#  'https://lu.ma/rdbts77j',
#  'https://lu.ma/vyozu7eq',
#  'https://lu.ma/rotky4am',
#  'https://lu.ma/mi17jr8p',
#  'https://lu.ma/wrxzfek3',
#  'https://lu.ma/fyu8iqnk',
#  'https://lu.ma/myb0z44f']

# %% [markdown]
# ## Firecrawl Extract

# %% [markdown]
# ### Imports

# %%
from firecrawl import FirecrawlApp
from pydantic import BaseModel, Field
from typing import Any, Optional, List

# %% [markdown]
# ### Extract Event Cards

# %%
# extract name, date, location, and description from each event URL

class NestedModel1(BaseModel):
    event_name: str
    event_date: str
    event_location_city: str
    event_description: str

class ExtractSchema(BaseModel):
    events: list[NestedModel1]

# Initialize an empty list to store the results
results = []

# Process each link in the links_list
for link in links_list:
    data = app.extract([link], {
        'prompt': 'Extract the name, date, location, and description of each event. Ensure that the name, date, and location are always captured.',
        'schema': ExtractSchema.model_json_schema(),
    })
    # Append a dictionary containing the link and its corresponding data
    results.append({
        'url': link,
        'result': data
    })

# Convert the results to JSON if needed
import json
results_json = json.dumps(results, indent=2)

# Print or use the JSON results as needed
pprint.pprint(results_json)
# Out:
# ('[\n'
#  '  {\n'
#  '    "url": "https://lu.ma/aidevfeb",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 12, 2025",\n'
#  '            "event_name": "AI Dev Tools Night @ Cloudflare HQ (February)",\n'
#  '            "event_description": "Join us for networking & learning '
#  'opportunities with awesome speakers & dev tool builders. We\\u2019ll '
#  'kickstart it with up to 4 lightning talks by AI dev tool builders, followed '
#  'by plenty of time for networking, asking questions, and further '
#  'discussions.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:56:28.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/z9blbdti",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 12, 2025",\n'
#  '            "event_name": "OneSixOne Ventures x Grace Gong Early Stage '
#  'Founders Happy Hour",\n'
#  '            "event_description": "Join Us for an Exclusive Founder & VC '
#  'Happy Hour! Exclusive Founders Happy Hour in San Francisco, hosted by Grace '
#  'Gong (Smart Venture Media) and Christopher Kennamer (OneSixOne Ventures). '
#  'Refreshments: snacks and drinks provided.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:56:38.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/sfdata",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 12, 2025",\n'
#  '            "event_name": "SF Data + AI Happy Hour",\n'
#  '            "event_description": "We\'re bringing together the brightest '
#  'minds in Data Science and Artificial Intelligence from across Silicon Valley '
#  'for an evening of innovation, collaboration, and networking.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:56:47.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/thoughtexperiments",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Wednesday, February 12",\n'
#  '            "event_name": "The Thought Experiment Lab",\n'
#  '            "event_description": "I\'m interested in discussing some such '
#  'interesting philosophical thought experiments, and hopefully gaining some '
#  "insight together into the issues all around us. At each meeting, we'll do "
#  'some quick reading to explain and provide background on a popular thought '
#  'experiment, and take the remaining time to share and discuss our '
#  'perspectives.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:56:54.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/5ycmcpa8",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 13, 2025",\n'
#  '            "event_name": "Thursday Crypto Run and Coffee",\n'
#  '            "event_description": "Join Us for Thursday\'s Presidio Runs! '
#  'Looking for a fun way to stay active, connect with others, and learn more '
#  'about what crypto and DAOs are about? Every Thursday at 4 PM, we\\u2019ll '
#  'meet for a 30-45 minute run around the beautiful Presidio in San Francisco. '
#  'Perfect for beginners and intermediates, this social run is where '
#  'you\\u2019ll break a sweat but enjoy every step! After the run, we\\u2019ll '
#  'gather at the House of Web3 for coffee, great conversations, and a chance to '
#  'explore the coworking space.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:57:02.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/0zo4ebka",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2025-02-13T17:00:00-08:00",\n'
#  '            "event_name": "Immigrant Founders Networking @ Microsoft '
#  'Reactor",\n'
#  '            "event_description": "Get ready to network and meet vetted '
#  'immigrant founders, investors, and operators at Immigrant Founders '
#  "Networking hosted by OpenSphere. Whether you're a tech enthusiast, a fellow "
#  'founder, or just curious about the future of the Immigrant founder '
#  'ecosystem, this is the place to be.",\n'
#  '            "event_location_city": "San Francisco"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:57:17.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/6pk5espk",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Thursday, February 13",\n'
#  '            "event_name": "Groq Developer Meetup",\n'
#  '            "event_description": "Are you interested in the field of GenAI? '
#  'Do you want to see how Groq can help you build faster and better LLM '
#  'applications? Join us for pizza and drinks with fellow developers and '
#  'Groqsters.\\n\\n5:30 - 6:00 - Networking/Registration\\n6:00 - 6:30 - '
#  'Welcome and AMA w/ Graham Steele, Sr. Product Marketing Manager\\n6:30 - '
#  '7:30 - Community demos powered by Groq\\n7:30 - 8:30 - Networking",\n'
#  '            "event_location_city": "Mountain View, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:57:29.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/trends2025",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2025-02-13",\n'
#  '            "event_name": "Funding Trends for Early Stage Founders in 2025 '
#  '(Crunchbase, VC Panel, & Pitch)",\n'
#  '            "event_description": "Curious about the funding landscape in '
#  '2025? Join us for an evening packed with actionable insights, inspiring '
#  'conversations, and networking opportunities. Start with an exclusive '
#  'presentation from Jeanie Fang, Director of Data Management and AI at '
#  'Crunchbase, sharing the latest funding trends. Then, dive into a lively '
#  'panel discussion where top venture capitalists will discuss the trends '
#  'shaping the future of startups, from industry hotspots to innovative funding '
#  'models and economic shifts.",\n'
#  '            "event_location_city": "San Francisco"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:57:39.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/vgss0zqv",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Thursday, February 13",\n'
#  '            "event_name": "Love for Design Happy Hour",\n'
#  '            "event_description": "Come hang out, unwind, and celebrate the '
#  'season of love with drinks, bites, and plenty of design talk. Whether '
#  'you\\u2019re catching up with old friends or meeting new ones, this is the '
#  'perfect chance to relax and connect.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:57:55.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/LSEevent",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Thursday, February 13",\n'
#  '            "event_name": "Reality of MedTech In 2025",\n'
#  '            "event_description": "Join us for an eye-opening panel '
#  'discussion on the \\"Reality of MedTech 2025\\", where we will explore the '
#  'pitfalls and challenges of the MedTech journey. Learn what paths to avoid '
#  'and how to set yourself up for sustainable success in this dynamic and '
#  'evolving industry.",\n'
#  '            "event_location_city": "San Jose, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:58:05.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/kf9v1pd9",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Thursday, February 13",\n'
#  '            "event_name": "Single\'s Run & Mingle",\n'
#  '            "event_description": "Join Fat Boys Run Club and Paloma for a '
#  'Valentine\\u2019s Day social jog '
#  '\\ud83c\\udfc3\\u200d\\u2642\\ufe0f\\ud83d\\udc98. We\\u2019re hitting the '
#  'pavement with a lighthearted group run, followed by a flirty social where '
#  'you can cool down with drinks, laughter, and maybe a few questionable '
#  'pick-up lines. Run starts from Oracle Park @ 6PM. No pressure, no '
#  'expectations\\u2014just a bunch of people seeing if running in the same '
#  'direction leads anywhere interesting. Drinks after the run at the Alchemist '
#  'Bar & Lounge.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:58:22.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/rxpzx3gt",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Thursday, February 13",\n'
#  '            "event_name": "119th SF Hardware Meetup @ Humanmade | Wildfire '
#  'Prevention + Recovery",\n'
#  '            "event_description": "Join for our first demo night of the year '
#  'exploring how hardware is helping respond to natural disasters. There will '
#  'be a chance for an open mic. All demos and standup pitches welcome.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:58:32.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/thfrtcq7",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Thursday, February 13",\n'
#  '            "event_name": "ODF Explorer Event",\n'
#  '            "event_description": "We\\u2019re hosting another get-together '
#  'for people who are considering what\\u2019s next. Past events have led to '
#  'people finding co-founders, angel investors, and other great opportunities '
#  '\\u2014 including learning more about ODF and meeting alumni.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:58:42.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/rdbts77j",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 14, 2025",\n'
#  '            "event_name": "NBA All-Star Weekend: Buzzer Beater Brunch",\n'
#  '            "event_description": "You are invited to a Women\'s Economic '
#  'EmpowHERment brunch tipping off NBA All-Star Weekend 2025 curated by '
#  'Untapped Investing - an angel investment group who come together as a '
#  'powerful collective catalyst for change in venture - in partnership with '
#  'PlayersTV! Our morning will spotlight two transformative conversations: 1. '
#  'The \\"Untold HERstories\\" Panel - An all-female powerhouse discussion '
#  'featuring remarkable women who are revolutionizing professional sports and '
#  'business beyond the court. 2. The \\"EmpowHER\\" Pitch Session - A live '
#  '\\"boardroom\\" experience where three industry-disrupting Black founders '
#  'will pitch their ventures, followed by dynamic Q&A with prominent venture '
#  'capital luminaries for an intimate view into the investment landscape and '
#  'decision-making process. Boozy networking brunch follows featuring Old '
#  'Hillside Bourbon specialty breakfast cocktails with an exclusive preview of '
#  '\\"The Trifecta\\" blend honoring three pioneering Black female horse racing '
#  'legends.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:58:51.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/vyozu7eq",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 14, 2025",\n'
#  '            "event_name": "Brotherhood Deli Speakeasy",\n'
#  '            "event_description": "The NBPA Speakeasy is popping up in San '
#  'Francisco for an exclusive two-day experience. On Friday, tip things off '
#  'with an exclusive pre-game card party featuring classics like Spades, Uno, '
#  'and more with prizes provided by Cash App. Elevate your evening with '
#  'artfully curated cocktails crafted from Maker\\u2019s Mark, as electrifying '
#  'beats from our resident DJ set the perfect vibe. Sip. Play. Celebrate.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:58:59.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/rotky4am",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 14, 2025",\n'
#  '            "event_name": "Brotherhood Deli Player Appearance with Jaren '
#  'Jackson Jr.",\n'
#  '            "event_description": "Get ready to kick off your morning with a '
#  'slam dunk of excitement at the Brotherhood Deli Player Appearance! Hosted by '
#  'the NBPA and NBA 2K, this event is your chance to meet one of your favorite '
#  'basketball players up close and personal. Snap some selfies, and soak in the '
#  "atmosphere with fellow fans. Don't miss out on the chance to make "
#  'unforgettable memories and maybe even snag an autograph!",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:59:08.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/mi17jr8p",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 14, 2025",\n'
#  '            "event_name": "Brotherhood Deli Happy Hour",\n'
#  '            "event_description": "Get ready to kick off your weekend with '
#  'some serious fun at the Brotherhood Deli Happy Hour! Join us on February '
#  '14th from 3:00 PM to 5:00 PM at Parklab Gardens for an afternoon filled with '
#  'free, premium plant-based bites brought to you by Beyond Meat, refreshing '
#  "drinks, and great company. Whether you're a local or visiting for the "
#  'all-star festivities, come mingle, relax, and enjoy the lively atmosphere. '
#  "Don't miss out on this perfect opportunity to unwind and make new friends. "
#  'See you there!",\n'
#  '            "event_location_city": "San Francisco"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:59:17.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/wrxzfek3",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Friday, February 14",\n'
#  '            "event_name": "\\ud83c\\udf39 Valentine\\u2019s Day Tech Singles '
#  'Mixer at Mission Dolores Manor \\ud83c\\udf39",\n'
#  '            "event_description": "Join us for the ultimate Hosted, '
#  'Intentional Dating Singles Mixer for the tech industry in San Francisco in '
#  'the lovely parlors of Mission Dolores Manor (MDM)! This event is designed to '
#  'help you break free from the routine, connect with like-minded individuals, '
#  'and maybe even meet your future partner. We will be using prompts from '
#  'Esther Perel to lighten up the mood, and get you talking about deep things '
#  'you want to find in a partner, work on yourself and manifest in your 2025 '
#  'relationship.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T19:59:29.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/fyu8iqnk",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "February 15, 2025",\n'
#  '            "event_name": "Multimodal AI Agents - 2 day Hackathon",\n'
#  '            "event_description": "CreatorsCorner, collaborating with Google '
#  'Deepmind, Weights & Biases, Together.ai, Stytch, Senso, LlamaIndex and '
#  'others enthusiastically welcomes individuals and teams to join our '
#  'hackathon! Seize this opportunity to create cutting-edge solutions that '
#  'enhance human potential through AI-powered software.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T20:00:33.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": "https://lu.ma/myb0z44f",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Saturday, February 15",\n'
#  '            "event_name": "Founders Running Club :: SF",\n'
#  '            "event_description": "Founders Running Club (FRC) brings '
#  'founders, investors, operators and creators together for weekly easy runs '
#  'and networking. We like to be comfortable when we run and finish with coffee '
#  'and more conversations. Choose your pace or follow a pacer\\u2014pets, '
#  'friends, family, are welcome.",\n'
#  '            "event_location_city": "San Francisco, California"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-12T20:00:44.000Z"\n'
#  '    }\n'
#  '  }\n'
#  ']')

# %% [markdown]
# # Semantic Filtering w/ OpenAI + Structured Outpus

# %% [markdown]
# ## Imports

# %%
from openai import OpenAI

# %%
# Initialize OpenAI client
client = OpenAI(api_key=openai_api_key)

# %%
# Category Prompt

DESIRED_CATEGORY = """
AI related social events.
"""

# %%
import json
from pydantic import BaseModel, ValidationError
import openai

class CategoryMatch(BaseModel):
    belongs_to_category: bool
    confidence: float

def belongs_to_category(event_name: str, event_description: str, desired_category: str) -> tuple[bool, float]:
    system_instructions = (
        "You are an event classifier. "
        "Given: a desired_category, an event_name, and an event_description, "
        "determine if the event belongs to the desired_category. "
        "Output only valid JSON with the exact format: "
        "{ \"belongs_to_category\": boolean, \"confidence\": float }. "
        "Where 'belongs_to_category' is True if the event belongs to the specified desired_category, "
        "otherwise False, and 'confidence' is a float between 0 and 1. No additional keys or text."
    )

    user_prompt = (
        f"desired_category: {desired_category}\n"
        f"event_name: {event_name}\n"
        f"event_description: {event_description}"
    )

    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_instructions},
                {"role": "user", "content": user_prompt},
            ],
            temperature=0.7
        )
        
        message_content = response.choices[0].message.content.strip()
        
        if not message_content:
            return False, 0.0
            
        parsed_args = json.loads(message_content)

        classification = CategoryMatch(**parsed_args)
        return classification.belongs_to_category, classification.confidence

    except (JSONDecodeError, ValidationError) as e:
        return False, 0.0

# Parse the JSON string into a Python object
events_data = json.loads(results_json)

# Desired category
DESIRED_CATEGORY = "AI Events"

# Initialize a list to store the results
filtered_events = []

# Process each event
for event_data in events_data:
    url = event_data["url"]
    for event in event_data["result"]["data"]["events"]:
        name = event["event_name"]
        description = event["event_description"]
        belongs, confidence = belongs_to_category(name, description, DESIRED_CATEGORY)
        
        # Only store and print results that are True with confidence above 0.7
        if belongs and confidence > 0.7:
            filtered_events.append({
                "url": url,
                "event_name": name,
                "event_description": description,  # Added missing description field
                "belongs_to_category": belongs,
                "confidence": confidence
            })
            
            print(f"Event URL: {url}")
            print(f"Event: {name}")
            print(f"Belongs to '{DESIRED_CATEGORY}': {belongs} with confidence {confidence}\n")

# Now `filtered_events` contains all the results that are True with confidence above 0.7
# Out:
# Event URL: https://lu.ma/aidevfeb
# Event: AI Dev Tools Night @ Cloudflare HQ (February)
# Belongs to 'AI Events': True with confidence 0.95
#
# Event URL: https://lu.ma/sfdata
# Event: SF Data + AI Happy Hour
# Belongs to 'AI Events': True with confidence 0.95
#
# Event URL: https://lu.ma/6pk5espk
# Event: Groq Developer Meetup
# Belongs to 'AI Events': True with confidence 0.85
#
# Event URL: https://lu.ma/trends2025
# Event: Funding Trends for Early Stage Founders in 2025 (Crunchbase, VC Panel, & Pitch)
# Belongs to 'AI Events': True with confidence 0.85
#
# Event URL: https://lu.ma/fyu8iqnk
# Event: Multimodal AI Agents - 2 day Hackathon
# Belongs to 'AI Events': True with confidence 0.95

# %% [markdown]
# # Discord Notification Test

# %%
import json
import requests

# Desired confidence threshold
CONFIDENCE_THRESHOLD = 0.95

def send_event_notification(event_name: str, event_description: str, url: str):
    """Send a new event notification to Discord"""
    message = {
        "embeds": [
            {
                "title": "🎉 New AI Event Detected!",
                "description": f"**Event Name:** {event_name}\n\n"
                               f"**Description:** {event_description}\n\n"
                               f"[View Event]({url})",
                "color": 5814783,  # Example color
            }
        ]
    }

    try:
        print(f"Sending notification for event: {event_name}")
        response = requests.post(DISCORD_WEBHOOK_URL, json=message)
        if response.status_code == 204:  # Discord returns 204 on success
            print("Successfully sent Discord notification")
        else:
            print(f"Discord API returned status {response.status_code}: {response.text}")
                    
    except requests.RequestException as e:
        print(f"Error sending Discord notification: {str(e)}")

# Process each filtered event
for event in filtered_events:
    url = event["url"]
    name = event["event_name"]
    confidence = event["confidence"]
    description = event.get("event_description", "")  # Ensure description is correctly extracted
    print(f"Processing event: {name} with confidence {confidence}")
    if confidence >= CONFIDENCE_THRESHOLD:
        # Ensure the correct description is passed
        send_event_notification(name, description, url)
# Out:
# Processing event: AI Dev Tools Night @ Cloudflare HQ (February) with confidence 0.95
# Sending notification for event: AI Dev Tools Night @ Cloudflare HQ (February)
# Successfully sent Discord notification
# Processing event: SF Data + AI Happy Hour with confidence 0.95
# Sending notification for event: SF Data + AI Happy Hour
# Successfully sent Discord notification
# Processing event: Groq Developer Meetup with confidence 0.85
# Processing event: Funding Trends for Early Stage Founders in 2025 (Crunchbase, VC Panel, & Pitch) with confidence 0.85
# Processing event: Multimodal AI Agents - 2 day Hackathon with confidence 0.95
# Sending notification for event: Multimodal AI Agents - 2 day Hackathon
# Successfully sent Discord notification
