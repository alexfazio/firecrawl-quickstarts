# %% [markdown]
# <a href="https://colab.research.google.com/github/alexfazio/firecrawl-quickstart/blob/main/events-scout-examples/eventbrite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Eventbrite AI Event Scout
# By [Alex Fazio](https://x.com/alxfazio/)
# Github repo: [social-crawler](https://github.com/alexfazio/social-crawler)
#
# This Jupyter notebook demonstrates how to build an automated event discovery pipeline using Firecrawl's scraping and extraction capabilities combined with AI filtering. By the end of this tutorial, you'll be able to:
#
# - Use Firecrawl to scrape event listings from Eventbrite by location
# - Extract structured event data using Firecrawl's LLM extraction
# - Implement AI-powered semantic filtering with OpenAI
# - Set up automated Discord notifications for matching events
#
# This workflow is designed for developers and community managers who want to automatically track relevant in-person events across multiple cities worldwide.
#
# **Key Firecrawl Uses:**
# - Location-based URL construction for event discovery
# - Structured data extraction from event pages
# - Schema validation for consistent event data formatting
#
# **Practical Application:**
# Automatically find and notify your team about AI-related meetups/conferences in specified cities, filtering out irrelevant events through semantic analysis.
#
# Requirements
# Before proceeding, ensure you have:
# - Firecrawl API key (for web scraping/extraction)
# - OpenAI API key (for AI filtering)
# - Discord webhook URL (for notifications)
#
# We'll be using the following packages:
# - firecrawl-py: For location-based scraping and structured data extraction
# - openai: For semantic event filtering
# - requests: For Discord webhook integration

# %% [markdown]
# ## Input API Keys

# %%
from getpass import getpass
openai_api_key = getpass("Enter your OpenAI API key: ")
firecrawl_api_key = getpass("Enter your Firecrawl API key: ")
DISCORD_WEBHOOK_URL = getpass("Enter your Discord WEbhook URL: ")

# %% [markdown]
# # Firecrawl Scrape

# %% [markdown]
# ## Install Dependencies

# %%
# %pip install requests python-dotenv openai firecrawl-py -q
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports

# %%
import os
import requests
import json
import pprint
from firecrawl import FirecrawlApp

# %% [markdown]
# ## Define City of Interest

# %%
# Define hierarchical location structure
locations = {
    "Americas": {
        "United States": [
            'atlanta', 'austin', 'boston', 'chicago', 'dallas', 'denver',
            'houston', 'los-angeles', 'miami', 'nyc', 'philadelphia',
            'phoenix', 'portland', 'salt-lake-city', 'san-diego', 'sf',
            'seattle', 'washington-dc'
        ],
        "Canada": ['montreal', 'toronto', 'vancouver', 'waterloo'],
        "Mexico": ['mexico-city'],
        "Brazil": ['sao-paulo'],
        "Colombia": ['bogota'],
        "Argentina": ['buenos-aires']
    },
    "Europe": {
        "Italy": ['milan'],
        "France": ['paris'],
        "Germany": ['berlin', 'munich'],
        "UK": ['london'],
        "Spain": ['barcelona', 'madrid'],
        "Netherlands": ['amsterdam'],
        "Switzerland": ['zurich'],
        "Sweden": ['stockholm'],
        "Portugal": ['lisbon'],
        "Belgium": ['brussels'],
        "Denmark": ['copenhagen'],
        "Finland": ['helsinki'],
        "Turkey": ['istanbul']
    },
    "Asia": {
        "Japan": ['tokyo'],
        "India": ['bengaluru', 'mumbai', 'new-delhi'],
        "China": ['hong-kong'],
        "Singapore": ['singapore'],
        "South Korea": ['seoul'],
        "Thailand": ['bangkok'],
        "Vietnam": ['ho-chi-minh-city'],
        "Indonesia": ['jakarta'],
        "Malaysia": ['kuala-lumpur'],
        "Philippines": ['manila'],
        "Taiwan": ['taipei'],
        "Israel": ['tel-aviv'],
        "UAE": ['dubai']
    },
    "Africa": {
        "Nigeria": ['lagos'],
        "Kenya": ['nairobi'],
        "South Africa": ['capetown']
    },
    "Oceania": {
        "Australia": ['melbourne', 'sydney']
    }
}

# Region selection
print("Select a region:")
regions = list(locations.keys())
for idx, region in enumerate(regions, 1):
    print(f"{idx}. {region}")
    
while True:
    try:
        region_sel = int(input("\nEnter region number: ")) - 1
        selected_region = regions[region_sel]
        break
    except (ValueError, IndexError):
        print("Invalid input. Please enter a valid number from the list.")

# Nation selection
print(f"\nSelect a nation in {selected_region}:")
nations = list(locations[selected_region].keys())
for idx, nation in enumerate(nations, 1):
    print(f"{idx}. {nation}")

while True:
    try:
        nation_sel = int(input("\nEnter nation number: ")) - 1
        selected_nation = nations[nation_sel]
        break
    except (ValueError, IndexError):
        print("Invalid input. Please enter a valid number from the list.")

# City selection
print(f"\nSelect a city in {selected_nation}:")
cities = locations[selected_region][selected_nation]
for idx, city in enumerate(cities, 1):
    print(f"{idx}. {city.replace('-', ' ').title()}")

while True:
    try:
        city_sel = int(input("\nEnter city number: ")) - 1
        selected_city = cities[city_sel]
        break
    except (ValueError, IndexError):
        print("Invalid input. Please enter a valid number from the list.")

# Create city variable
city = f"{selected_nation.lower().replace(' ', '-')}--{selected_city}"
print(f"\nSelected location: {city}")
# Out:
# Select a region:
# 1. Americas
# 2. Europe
# 3. Asia
# 4. Africa
# 5. Oceania
#
# Select a nation in Europe:
# 1. Italy
# 2. France
# 3. Germany
# 4. UK
# 5. Spain
# 6. Netherlands
# 7. Switzerland
# 8. Sweden
# 9. Portugal
# 10. Belgium
# 11. Denmark
# 12. Finland
# 13. Turkey
#
# Select a city in Italy:
# 1. Milan
#
# Selected location: italy--milan

# %% [markdown]
# ## Define Timeframe

# %%
# Timeframe selection options
timeframe_options = [
    'events--today',
    'events--tomorrow',
    'events--this-weekend',
    'events--this-week',
    'events--next-week',
    'events--this-month',
    'events--next-month'
]

# Display timeframe choices
print("Select a timeframe for events:")
for idx, timeframe in enumerate(timeframe_options, 1):
    # Format display name with "events" prefix and title case
    display_name = "events " + timeframe.split('--')[1].replace('-', ' ').title()
    print(f"{idx}. {display_name}")

# Get valid user input
while True:
    try:
        selection = int(input("\nEnter timeframe number (1-7): "))
        if 1 <= selection <= len(timeframe_options):
            timeframe = timeframe_options[selection - 1]
            break
        else:
            print(f"Please enter a number between 1 and {len(timeframe_options)}")
    except ValueError:
        print("Invalid input. Please enter a number.")

# Display confirmation with consistent formatting
display_name = "events " + timeframe.split('--')[1].replace('-', ' ').title()
print(f"\nSelected timeframe: {display_name}")
# Out:
# Select a timeframe for events:
# 1. events Today
# 2. events Tomorrow
# 3. events This Weekend
# 4. events This Week
# 5. events Next Week
# 6. events This Month
# 7. events Next Month
#
# Selected timeframe: events Today

# %% [markdown]
# ## Instantiate FirecrawlApp

# %%
# Initialize Firecrawl client
app = FirecrawlApp(api_key=firecrawl_api_key)

# %% [markdown]
# ## Firecrawl Extract

# %% [markdown]
# ### Imports

# %%
from firecrawl import FirecrawlApp
from pydantic import BaseModel, Field
from typing import Any, Optional, List

# %% [markdown]
# ### Extract the Total Number of Pages Returned by the Search

# %%
class ExtractSchema(BaseModel):
    total_search_pages_returned: float

data = app.extract(
    [f'https://www.eventbrite.com/d/{city}/{timeframe}/'],
    {
        'prompt': 'Extract the total number of pages returned by the event search.',
        'schema': ExtractSchema.model_json_schema(),
    }
)

# Store the total pages in a variable with error handling
try:
    total_pages = int(data['data']['total_search_pages_returned'])
    print(f"Total search pages returned: {total_pages}")
except (KeyError, TypeError) as e:
    print(f"Error extracting page count: {str(e)}")
    print("Defaulting to 1 page")
    total_pages = 1  # Fallback value
# Out:
# Total search pages returned: 9

# %% [markdown]
# ## Firecrawl Scrape

# %% [markdown]
# Extract all event cards found in all the returned search results.

# %%
# Firecrawl Scrape

# Verify city selection exists
if 'city' not in locals():
    raise ValueError("City not selected - please run the city selection cell first")

# Initialize list to collect all events
links_list = []

# Scrape all pages
for page in range(1, total_pages + 1):
    print(f"Scraping page {page}/{total_pages}")
    page_url = f'https://www.eventbrite.com/d/{city}/{timeframe}/?page={page}'
    
    response = app.scrape_url(
        url=page_url,
        params={
            'formats': ['links'],
            'includeTags': ['a.event-card-link']
        }
    )
    
    # Add page results to main list
    page_links = response.get('links', [])
    links_list.extend(page_links)
    print(f"Found {len(page_links)} events on this page")

# Extract and validate all links
if not links_list:
    print(f"No events found for {city.replace('-', ' ').title()}")
else:
    print(f"\nTotal {len(links_list)} events found across {total_pages} pages:")
    pprint.pprint(links_list)
# Out:
# Scraping page 1/9
# Found 20 events on this page
# Scraping page 2/9
# Found 19 events on this page
# Scraping page 3/9
# Found 20 events on this page
# Scraping page 4/9
# Found 19 events on this page
# Scraping page 5/9
# Found 20 events on this page
# Scraping page 6/9
# Found 20 events on this page
# Scraping page 7/9
# Found 19 events on this page
# Scraping page 8/9
# Found 19 events on this page
# Scraping page 9/9
# Found 0 events on this page
#
# Total 156 events found across 9 pages:
# ['https://www.eventbrite.it/e/biglietti-cattolica-goes-to-gattopardo-1244243468709?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/klinikum-the-power-of-patient-centered-design-tickets-1123834091019?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/klinikum-revolutionizing-healthcare-the-power-of-patient-centered-design-tickets-1123728324669?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/ceramica-meditativa-dharana-pottery-corso-da-mini-design-club-tickets-1093556068639?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-corso-di-acrofit-allenamento-a-corpo-libero-con-acrobatica-978157022987?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/cooking-top-italian-food-selection-cooking-class-by-cozymealtm-tickets-929031938537?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/italian-gastronomy-of-your-choice-cooking-class-by-cozymealtm-tickets-929030704847?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/authentic-milanese-pasta-class-cooking-class-by-cozymealtm-tickets-929064335437?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/hands-on-pasta-and-tiramisu-making-in-milan-cooking-class-by-cozymealtm-tickets-929029541367?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/dive-into-milans-secrets-with-an-unforgettable-outdoor-escape-game-tickets-1062270853719?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/explore-milans-hidden-gems-on-an-exciting-city-scavenger-hunt-tickets-1062284313979?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/milan-vintage-shopping-guide-tickets-1033535150457?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com.au/e/integrating-blockchain-and-ai-artificial-intelligence-milan-tickets-881721882887?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/milan-business-the-science-of-sales-marketing-for-beginners-tickets-1214183237749?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/an-epic-fun-filled-scavenger-hunt-milan-inspires-tickets-1033819882097?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/yin-yoga-tickets-1209423611579?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-esperienza-cioccolato-la-fabbrica-del-cioccolato-di-enrico-rizzi-1079148294599?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/street-food-tour-tickets-1230297596229?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/royal-highlights-of-milan-outdoor-escape-game-tickets-734076311007?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/milan-outdoor-escape-game-fashion-and-art-highlights-tickets-734085147437?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/milan-outdoor-escape-game-fashion-and-art-highlights-tickets-734085147437?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/startups-develop-innovative-product-with-minimum-viable-thinking-tickets-693001063837?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/milan-navigli-outdoor-escape-game-magic-along-the-water-tickets-730986037917?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/manzonis-milan-outdoor-escape-game-the-betrothed-i-promessi-sposi-tickets-769419332937?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/milan-outdoor-escape-game-leonardo-da-vinci-tickets-469426155267?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/street-art-milan-outdoor-escape-game-tickets-517786953717?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/milan-outdoor-escape-game-the-lost-duke-of-milan-tickets-655659403927?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/bar-hopping-in-milan-tickets-1208319499149?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/milan-vintage-shopping-tour-tickets-759028242907?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com.au/e/unravelling-nfts-non-fungible-tokens-milan-tickets-493312560147?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/como-outdoor-escape-game-mystery-heist-tickets-654596544887?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/highlights-of-como-a-city-adventure-tickets-1217580689619?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/crack-bergamos-enigmas-in-an-unforgettable-outdoor-escape-tickets-1061366839789?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/bergamo-outdoor-escape-game-atalanta-the-hero-tickets-791701539617?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/hunt-for-bergamos-best-kept-secrets-with-a-citywide-scavenger-adventure-tickets-1061374653159?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/adventurous-scavenger-hunt-downtown-dash-dazzle-hunt-tickets-1127698058249?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-mamacita-justme-milano-giovedi-infoline-lista-cugini-393382724181-728570523047?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/stormy-grooves-tickets-1244764095919?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-nordikhouse-benessere-artico-1181325048019?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/biglietti-wunderkit-wsara-maragotto-studio-fludd-1230745656389?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/jeme-bocconi-networking-aperitivo-tickets-1242462752539?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/groove-on-stage-quelli-dopo-friends-tickets-1206585743439?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/hyperitif-j-dilla-tribute-malasartoria-milano-live-tickets-1225805299649?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-hr-in-trasformazione-costruire-il-futuro-delle-risorse-umane-1194564999069?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-henna-tattoo-experience-valentine-day-music-tattoo-free-drinks-food-1217830336319?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/java-release-party-tickets-1237204254229?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-storia-di-una-brava-ragazza-1220928021579?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-quiz-night-sanremo-edition-ostello-bello-milano-duomo-1244597116479?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/sanremo-in-famiglia-terza-serata-in-sede-live-moment-tickets-1235813293829?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-55-milano-laperitivo-cantato-1218427161439?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/rock-jam-rockin1000-tickets-1219459850239?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-ollusion-malaga-sin-city-magia-ologrammi-melodic-techno-1244069057039?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/galentines-coffee-speed-friending-132-tickets-1234472062169?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-stand-up-comedy-bar-bah-1245151935959?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/il-vento-della-memoria-tickets-1230423984259?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-republic-milanobaddie-info-3355290025-1245440920319?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-republic-milanogiovedi-info-3355290025-1245432796019?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/picture-this-idioms-made-simple-tickets-1244482082409?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/eskere-invites-tickets-1234531750699?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-justme-milano-giovedi-13-febbraio-2025-info-al-351-6641431-1237768150859?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/letture-per-bambn-tickets-1242189304649?aff=ebdssbdestsearch',
#  'https://www.eventbrite.co.uk/e/free-online-workshop-how-to-discover-your-dream-career-tickets-1242189033839?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/finissage-andrea-branzi-civilizations-without-jewels-have-never-existed-tickets-1234739231279?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-manzila-in-concerto-1219513109539?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/visita-guidata-alla-mostra-libertad-tickets-1176601399459?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/sussurri-nell-underdark-tickets-1140200864479?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/cena-cantata-a-milano-tickets-1222360716809?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-menady-restaurant-dinner-show-info-393355290025-1232972316389?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-tony-effe-look-alike-competition-ostello-bello-milano-duomo-1230549539799?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/free-english-stand-up-comedy-open-mic-tickets-1137966792309?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/55-milano-laperitivo-cantato-tickets-1222010288669?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/discover-brescia-with-the-help-of-a-goddess-quest-experience-tickets-1006565322977?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-test-drive-leica-m11-p-new-old-camera-737972835617?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-play-clubgiovedi-african-music-valentines-delight-info-3355290025-1246160943929?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-play-club-thursday-african-music-valentines-delight-info-3355290025-1246169589789?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-test-drive-leica-q3-new-old-camera-739198762397?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/lis-sam-me-milan-il-duca-tickets-1151894119319?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-bicocca-tutti-i-giorni-aperitivo-fino-alle-2030-12-servito-al-tavolo-740706451937?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/gin-experience-tickets-1067530796349?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-55-milanothursday-live-music-show-info-39-3355290025-1215584278299?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-55-milanogiovedi-live-music-show-info-3355290025-1208530119119?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-citta-studi-tutti-i-giorni-aperitivo-fino-alle-2030-12-servito-al-tavolo-740716983437?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/thu-feb-13-redroom-members-club-present-thursday-knights-tickets-1246407531479?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/biglietti-giovedi-justme-milano-861708973737?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/bicocca-ogni-giovedi-sera-cena-in-varieta-and-music-tickets-723860214387?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-test-drive-leica-m11-p-con-esperto-a-supporto-leica-store-milano-747009975947?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-test-drive-leica-q3-43-leica-store-milano-1105477736669?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/robert-adams-compositions-of-earth-tickets-1048569398297?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/allineamento-e-guarigione-spirituale-tickets-1234359916739?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-il-festival-di-sanremo-sul-divano-di-materia-con-stefania-radman-1212539400989?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/intorno-a-lavaro-tickets-1220906627589?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/international-jazz-night-con-natalya-kozlova-postmodern-band-tickets-1225162186079?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-maledetto-karaoke-ostello-bello-como-625151814907?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/montagne-immaginarie-tickets-1217754730179?aff=ebdssbdestsearch',
#  'https://www.eventbrite.co.uk/e/data-biographies-tickets-1088544268209?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-speed-date-bergamo-855871303107?aff=ebdssbdestsearch',
#  'https://www.eventbrite.ch/e/biglietti-tai-chi-lugano-e-paradiso-meditazione-e-circolazione-energetica-1014252816477?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/biglietti-pop-up-milano-raincoats-1247183081169?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-la-buca-del-coboldo-serata-aperta-13022025-1234609372869?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-consulenze-complementari-societa-impiegati-commercio-525633914187?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-tandem-linguistici-1184792599559?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-serata-giochi-da-tavola-1143966096389?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/senza-pieta-tickets-1226067764689?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/visite-guidate-a-casa-luzzati-tickets-1243992457929?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/registrazione-caccia-al-tesoro-il-cammino-del-grifone-1210094327709?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/treasure-hunt-the-path-of-the-griffon-vulture-registration-1210184858489?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/hunt-for-genoas-hidden-treasures-on-an-interactive-city-scavenger-hunt-tickets-1061463579139?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/unlock-genoas-mysteries-with-an-exciting-outdoor-escape-game-tickets-1061457510989?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/genoa-career-advancing-secrets-for-professionals-just-like-you-tickets-992365039547?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/genoa-food-guided-tour-with-wine-tastings-tickets-1083886526779?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/genoa-historical-center-outdoor-escape-game-tickets-531001127667?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/meditazione-guidata-registration-1243563224079?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/unlock-turins-hidden-mysteries-with-a-thrilling-outdoor-escape-game-tickets-1063525576629?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/discover-turins-hidden-treasures-with-a-fun-city-scavenger-hunt-tickets-1063536348849?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/easy-vermouth-tasting-in-turin-city-center-tickets-1083886576929?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/amazing-scavenger-hunt-turin-treasure-trotters-tickets-1068005486159?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/treasure-hunt-the-prophecy-of-the-shadows-registration-1210195379959?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/registrazione-caccia-al-tesoro-la-profezia-delle-ombre-1210107256379?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/ghosts-of-turin-haunting-stories-outdoor-escape-game-tickets-531087355577?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-torino-magica-tour-1145699511079?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/romantic-turin-outdoor-escape-game-tickets-780441440357?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/adventurous-scavenger-hunt-mantovas-marvelous-mysterioso-hunt-tickets-1112860368319?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/a-thrilling-scavenger-hunt-brigs-downtown-delight-hunt-tickets-1137864155319?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/nella-fede-la-gioia-tickets-1206804838759?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/call-my-bluff-tickets-1205121594129?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/biglietti-il-viaggio-nella-maternita-un-dialogo-tra-fotografia-e-pedagogia-1244644407929?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-beer-pong-tournament-ostello-bello-genova-896410577167?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/biglietti-ric-amare-workshop-di-ricamo-1235960554289?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-lezione-di-prova-taekwondo-per-ragazzi-7-10-anni-414644772677?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-test-drive-leica-sl3-top-market-foto-video-746990176727?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-test-drive-leica-m11-top-market-foto-video-746985793617?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-mostra-darte-emergente-interzone-1247062881649?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/unlock-the-mysteries-of-verona-with-an-immersive-escape-game-tickets-1063594683329?aff=ebdssbdestsearch',
#  'https://www.eventbrite.sg/e/discover-veronas-hidden-gems-with-a-fun-scavenger-hunt-tickets-1063604944019?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-visita-guidata-mostra-mama-i-want-to-go-home-1216686264369?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/biglietti-candlelight-lunare-yoga-1225917414989?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-concerto-dell-orchestra-etnica-dellafrica-subsahariana-1216664770079?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/verona-leadership-secrets-how-to-avoid-costly-hiring-mistakes-tickets-1172855635779?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/premiazione-call-for-artist-turin-dry-gin-3rd-edition-tickets-1235896823669?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-presentazione-libro-il-segreto-nel-nome-di-amal-oursan-1216596676409?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/speed-date-genova-tickets-998447321817?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-speed-date-torino-852291024397?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/registrazione-aperitivo-allargilla-416589158387?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-djungle-studio-dday-live-9-1059597999139?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/biglietti-elab-on-tour-torino-1203222263179?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/fashion-experience-room-tickets-1138187773269?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-test-drive-leica-q3-43-leica-store-torino-1105603552989?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-thursday-wave-classe-settimanale-di-5ritmi-1123651324359?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/speed-date-verona-tickets-998453018857?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-federico-buffa-presenta-sport-per-umani-1080247000859?aff=ebdssbdestsearch',
#  'https://www.eventbrite.com/e/biglietti-speak-and-spritz-love-is-in-the-air-aperitivo-linguistico-1235997745529?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/magic-prerelease-di-aetherdrift-tickets-1139800396669?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-bandai-gunpla-assemblaggio-model-kit-1240575297109?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-star-wars-unlimited-costruito-premier-1241105753719?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-flesh-and-blood-evento-armory-1240988733709?aff=ebdssbdestsearch',
#  'https://www.eventbrite.it/e/biglietti-come-il-teatro-dellimprovvisazione-puo-far-emergere-le-tue-soft-skills-1139684138939?aff=ebdssbdestsearch']

# %% [markdown]
# ## Firecrawl Extract

# %% [markdown]
# ### Imports

# %%
from firecrawl import FirecrawlApp
from pydantic import BaseModel, Field
from typing import Any, Optional, List

# %% [markdown]
# ### Extract Event Cards

# %%
# extract name, date, location, and description from each event URL

# TEMPORARY SAFETY LIMIT - set to None to remove limit
MAX_EXTRACTIONS = 10  # Change this number or set to None for full processing

class NestedModel1(BaseModel):
    event_name: str
    event_date: str
    event_location_city: str
    event_description: str

class ExtractSchema(BaseModel):
    events: list[NestedModel1]

# Initialize an empty list to store the results
results = []

# Process each link in the links_list with safety limit
for link in links_list[:MAX_EXTRACTIONS] if MAX_EXTRACTIONS else links_list:
    data = app.extract([link], {
        'prompt': 'Extract the name, date, location, and description of each event. Ensure that the name, date, and location are always captured.',
        'schema': ExtractSchema.model_json_schema(),
    })
    # Append a dictionary containing the link and its corresponding data
    results.append({
        'url': link,
        'result': data
    })
    
if MAX_EXTRACTIONS:
    print(f"\n⚠️ TEMPORARY LIMIT ACTIVE: Processed first {MAX_EXTRACTIONS} events")
    print("To remove limit, set MAX_EXTRACTIONS = None at top of cell\n")

# Convert the results to JSON if needed
import json
results_json = json.dumps(results, indent=2)

# Print or use the JSON results as needed
pprint.pprint(results_json)
# Out:
# ⚠️ TEMPORARY LIMIT ACTIVE: Processed first 10 events
# To remove limit, set MAX_EXTRACTIONS = None at top of cell
#
# ('[\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.it/e/biglietti-cattolica-goes-to-gattopardo-1244243468709?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2025-02-13T23:30:00+01:00",\n'
#  '            "event_name": "CATTOLICA goes to GATTOPARDO",\n'
#  '            "event_description": "WELCOME TO MILAN - OFFICIAL PARTY '
#  'CATTOLICA EXCHANGE STUDENTS",\n'
#  '            "event_location_city": "Milano"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:58:12.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.com/e/klinikum-the-power-of-patient-centered-design-tickets-1123834091019?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Thursday, February 13, 2025",\n'
#  '            "event_name": "KLINIKUM+/ The Power of Patient-Centered '
#  'Design",\n'
#  '            "event_description": "In today\\u2019s rapidly evolving '
#  'healthcare landscape, the need for innovative solutions that prioritize the '
#  'patient experience has never been more critical. This lecture series explore '
#  'the principles and practice of patient-centered design, a methodology that '
#  'places the patient\\u2019s needs, values, and preferences at the core of '
#  'healthcare delivery and innovation. Participants will learn practical '
#  'strategies for integrating patient feedback, addressing diverse needs, and '
#  'leveraging design thinking to build empathetic and effective healthcare '
#  'systems.",\n'
#  '            "event_location_city": "Milan"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:58:19.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.com/e/klinikum-revolutionizing-healthcare-the-power-of-patient-centered-design-tickets-1123728324669?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "Thursday, February 13, 2025",\n'
#  '            "event_name": "KLINIKUM+/ Revolutionizing Healthcare: The Power '
#  'of Patient-Centered Design",\n'
#  '            "event_description": "learn & discuss how patient-centered '
#  'design is changing the healthcare landscape!",\n'
#  '            "event_location_city": "Milan"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:58:26.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.com/e/ceramica-meditativa-dharana-pottery-corso-da-mini-design-club-tickets-1093556068639?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2025-01-30",\n'
#  '            "event_name": "Ceramica meditativa- Dharana Pottery, corso da '
#  'Mini design club",\n'
#  '            "event_description": "Join a unique experience of meditative '
#  'pottery at Mini Spazio, as part of the Mini Design Club project. These '
#  'workshops focus on non-performance, meditative, and collective art '
#  'practices, where creative manual work merges with physical and mental '
#  'well-being.",\n'
#  '            "event_location_city": "Milano"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-02-06",\n'
#  '            "event_name": "Ceramica meditativa- Dharana Pottery, corso da '
#  'Mini design club",\n'
#  '            "event_description": "Join a unique experience of meditative '
#  'pottery at Mini Spazio, as part of the Mini Design Club project. These '
#  'workshops focus on non-performance, meditative, and collective art '
#  'practices, where creative manual work merges with physical and mental '
#  'well-being.",\n'
#  '            "event_location_city": "Milano"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-02-13",\n'
#  '            "event_name": "Ceramica meditativa- Dharana Pottery, corso da '
#  'Mini design club",\n'
#  '            "event_description": "Join a unique experience of meditative '
#  'pottery at Mini Spazio, as part of the Mini Design Club project. These '
#  'workshops focus on non-performance, meditative, and collective art '
#  'practices, where creative manual work merges with physical and mental '
#  'well-being.",\n'
#  '            "event_location_city": "Milano"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:58:39.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.it/e/biglietti-corso-di-acrofit-allenamento-a-corpo-libero-con-acrobatica-978157022987?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2025-02-13T20:00:00+01:00",\n'
#  '            "event_name": "CORSO DI ACROFIT: Allenamento a corpo libero con '
#  'acrobatica",\n'
#  '            "event_description": "RESTA IN FORMA CON ACROFIT: un allenamento '
#  'speciale e completo. Ginnastica a corpo libero con acrobatica",\n'
#  '            "event_location_city": "Solaro"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-02-20T20:00:00+01:00",\n'
#  '            "event_name": "CORSO DI ACROFIT: Allenamento a corpo libero con '
#  'acrobatica",\n'
#  '            "event_description": "RESTA IN FORMA CON ACROFIT: un allenamento '
#  'speciale e completo. Ginnastica a corpo libero con acrobatica",\n'
#  '            "event_location_city": "Solaro"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-02-27T20:00:00+01:00",\n'
#  '            "event_name": "CORSO DI ACROFIT: Allenamento a corpo libero con '
#  'acrobatica",\n'
#  '            "event_description": "RESTA IN FORMA CON ACROFIT: un allenamento '
#  'speciale e completo. Ginnastica a corpo libero con acrobatica",\n'
#  '            "event_location_city": "Solaro"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-03-06T20:00:00+01:00",\n'
#  '            "event_name": "CORSO DI ACROFIT: Allenamento a corpo libero con '
#  'acrobatica",\n'
#  '            "event_description": "RESTA IN FORMA CON ACROFIT: un allenamento '
#  'speciale e completo. Ginnastica a corpo libero con acrobatica",\n'
#  '            "event_location_city": "Solaro"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-03-13T20:00:00+01:00",\n'
#  '            "event_name": "CORSO DI ACROFIT: Allenamento a corpo libero con '
#  'acrobatica",\n'
#  '            "event_description": "RESTA IN FORMA CON ACROFIT: un allenamento '
#  'speciale e completo. Ginnastica a corpo libero con acrobatica",\n'
#  '            "event_location_city": "Solaro"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:58:51.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.com/e/cooking-top-italian-food-selection-cooking-class-by-cozymealtm-tickets-929031938537?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2024-02-17",\n'
#  '            "event_name": "Cooking Top Italian Food Selection - Cooking '
#  'Class by Cozymeal\\u2122",\n'
#  '            "event_description": "Phenomenal food and incredible company '
#  "await you at the chef's table! Join Cozymeal\\u2019s upcoming cooking class "
#  'Join \\u201cCooking Top Italian Food Selection\\u201d with Chef Francesca & '
#  'Chef Niccol\\u00f2 for an intimate 3-hour culinary experience and 5-course '
#  'meal.",\n'
#  '            "event_location_city": "Milan"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:59:01.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.com/e/italian-gastronomy-of-your-choice-cooking-class-by-cozymealtm-tickets-929030704847?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2024-07-01",\n'
#  '            "event_name": "Italian Gastronomy of Your Choice - Cooking Class '
#  'by Cozymeal\\u2122",\n'
#  '            "event_description": "Phenomenal food and incredible company '
#  "await you at the chef's table! Join Cozymeal\\u2019s upcoming cooking class "
#  'Join \\u201cItalian Gastronomy of Your Choice\\u201d with Chef Francesca & '
#  'Chef Niccol\\u00f2 for an intimate 3-hour culinary experience and 5-course '
#  'meal.",\n'
#  '            "event_location_city": "Milan"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:59:13.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.com/e/authentic-milanese-pasta-class-cooking-class-by-cozymealtm-tickets-929064335437?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2024-07-01T18:00:00-07:00",\n'
#  '            "event_name": "Authentic Milanese Pasta Class - Cooking Class by '
#  'Cozymeal\\u2122",\n'
#  '            "event_description": "Phenomenal food and incredible company '
#  "await you at the chef's table! Join Cozymeal\\u2019s upcoming cooking class "
#  'Join \\u201cAuthentic Milanese Pasta Class\\u201d with Chef Francesca & Chef '
#  'Niccol\\u00f2 for an intimate 3-hour culinary experience and 6-course '
#  'meal.",\n'
#  '            "event_location_city": "Milan"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-04-17T13:00:00-07:00",\n'
#  '            "event_name": "Authentic Milanese Pasta Class - Cooking Class by '
#  'Cozymeal\\u2122",\n'
#  '            "event_description": "Phenomenal food and incredible company '
#  "await you at the chef's table! Join Cozymeal\\u2019s upcoming cooking class "
#  'Join \\u201cAuthentic Milanese Pasta Class\\u201d with Chef Francesca & Chef '
#  'Niccol\\u00f2 for an intimate 3-hour culinary experience and 6-course '
#  'meal.",\n'
#  '            "event_location_city": "Milan"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:59:23.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.com/e/hands-on-pasta-and-tiramisu-making-in-milan-cooking-class-by-cozymealtm-tickets-929029541367?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2024-07-01",\n'
#  '            "event_name": "Hands-On Pasta and Tiramisu Making in Milan - '
#  'Cooking Class by Cozymeal\\u2122",\n'
#  '            "event_description": "Phenomenal food and incredible company '
#  "await you at the chef's table! Join Cozymeal\\u2019s upcoming cooking class "
#  'Join \\u201cHands-On Pasta and Tiramisu Making in Milan\\u201d with Chef '
#  'Francesca & Chef Niccol\\u00f2 for an intimate 3-hour culinary experience '
#  'and 4-course meal.",\n'
#  '            "event_location_city": "Milan"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-04-17",\n'
#  '            "event_name": "Hands-On Pasta and Tiramisu Making in Milan - '
#  'Cooking Class by Cozymeal\\u2122",\n'
#  '            "event_description": "Phenomenal food and incredible company '
#  "await you at the chef's table! Join Cozymeal\\u2019s upcoming cooking class "
#  'Join \\u201cHands-On Pasta and Tiramisu Making in Milan\\u201d with Chef '
#  'Francesca & Chef Niccol\\u00f2 for an intimate 3-hour culinary experience '
#  'and 4-course meal.",\n'
#  '            "event_location_city": "Milan"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:59:34.000Z"\n'
#  '    }\n'
#  '  },\n'
#  '  {\n'
#  '    "url": '
#  '"https://www.eventbrite.sg/e/dive-into-milans-secrets-with-an-unforgettable-outdoor-escape-game-tickets-1062270853719?aff=ebdssbdestsearch",\n'
#  '    "result": {\n'
#  '      "success": true,\n'
#  '      "data": {\n'
#  '        "events": [\n'
#  '          {\n'
#  '            "event_date": "2024-10-30",\n'
#  '            "event_name": "Dive into Milan\\u2019s secrets with an '
#  'unforgettable outdoor escape game!",\n'
#  '            "event_description": "Explore Milan with a thrilling escape '
#  'game! Solve puzzles to uncover the city\\u2019s iconic landmarks and hidden '
#  'wonders.",\n'
#  '            "event_location_city": "Milano"\n'
#  '          },\n'
#  '          {\n'
#  '            "event_date": "2025-04-14",\n'
#  '            "event_name": "Dive into Milan\\u2019s secrets with an '
#  'unforgettable outdoor escape game!",\n'
#  '            "event_description": "Explore Milan with a thrilling escape '
#  'game! Solve puzzles to uncover the city\\u2019s iconic landmarks and hidden '
#  'wonders.",\n'
#  '            "event_location_city": "Milano"\n'
#  '          }\n'
#  '        ]\n'
#  '      },\n'
#  '      "status": "completed",\n'
#  '      "expiresAt": "2025-02-13T19:59:44.000Z"\n'
#  '    }\n'
#  '  }\n'
#  ']')

# %% [markdown]
# # Semantic Filtering w/ OpenAI + Structured Outputs

# %% [markdown]
# ## Imports

# %%
from openai import OpenAI

# %%
# Initialize OpenAI client
client = OpenAI(api_key=openai_api_key)

# %% [markdown]
# ## Define Category of Interest

# %%
# Category Prompt

DESIRED_CATEGORY = """
AI related social events.
"""

# %% [markdown]
# ## Score and Filter Events

# %%
import json
from pydantic import BaseModel, ValidationError
import openai

class CategoryMatch(BaseModel):
    belongs_to_category: bool
    confidence: float

def belongs_to_category(event_name: str, event_description: str, desired_category: str) -> tuple[bool, float]:
    system_instructions = (
        "You are an event classifier. "
        "Given: a desired_category, an event_name, and an event_description, "
        "determine if the event belongs to the desired_category. "
        "Output only valid JSON with the exact format: "
        "{ \"belongs_to_category\": boolean, \"confidence\": float }. "
        "Where 'belongs_to_category' is True if the event belongs to the specified desired_category, "
        "otherwise False, and 'confidence' is a float between 0 and 1. No additional keys or text."
    )

    user_prompt = (
        f"desired_category: {desired_category}\n"
        f"event_name: {event_name}\n"
        f"event_description: {event_description}"
    )

    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_instructions},
                {"role": "user", "content": user_prompt},
            ],
            temperature=0.7
        )
        
        message_content = response.choices[0].message.content.strip()
        
        if not message_content:
            return False, 0.0
            
        parsed_args = json.loads(message_content)

        classification = CategoryMatch(**parsed_args)
        return classification.belongs_to_category, classification.confidence

    except (JSONDecodeError, ValidationError) as e:
        return False, 0.0

# Parse the JSON string into a Python object
events_data = json.loads(results_json)

# Desired category
DESIRED_CATEGORY = "AI Events"

# Initialize a list to store the results
filtered_events = []

# Process each event
for event_data in events_data:
    url = event_data["url"]
    for event in event_data["result"]["data"]["events"]:
        name = event["event_name"]
        description = event["event_description"]
        belongs, confidence = belongs_to_category(name, description, DESIRED_CATEGORY)
        
        # Only store and print results that are True with confidence above 0.7
        if belongs and confidence > 0.7:
            filtered_events.append({
                "url": url,
                "event_name": name,
                "event_description": description,
                "belongs_to_category": belongs,
                "confidence": confidence
            })
            
            print(f"Event URL: {url}")
            print(f"Event: {name}")
            print(f"Belongs to '{DESIRED_CATEGORY}': {belongs} with confidence {confidence}\n")

# Handle empty results
if not filtered_events:
    print(f"\n⚠️ No events passed the {DESIRED_CATEGORY} filter with confidence > 0.7")
else:
    print(f"\n✅ Found {len(filtered_events)} events matching {DESIRED_CATEGORY} criteria")

# Now `filtered_events` contains all the results that are True with confidence above 0.7
# Out:
# ⚠️ No events passed the AI Events filter with confidence > 0.7

# %% [markdown]
# # Discord Notification Test

# %%
import json
import requests

# Desired confidence threshold
CONFIDENCE_THRESHOLD = 0.95

def send_event_notification(event_name: str, event_description: str, url: str):
    """Send a new event notification to Discord"""
    message = {
        "embeds": [
            {
                "title": "🎉 New AI Event Detected!",
                "description": f"**Event Name:** {event_name}\n\n"
                               f"**Description:** {event_description}\n\n"
                               f"[View Event]({url})",
                "color": 5814783,  # Example color
            }
        ]
    }

    try:
        print(f"Sending notification for event: {event_name}")
        response = requests.post(DISCORD_WEBHOOK_URL, json=message)
        if response.status_code == 204:  # Discord returns 204 on success
            print("Successfully sent Discord notification")
        else:
            print(f"Discord API returned status {response.status_code}: {response.text}")
                    
    except requests.RequestException as e:
        print(f"Error sending Discord notification: {str(e)}")

# Process each filtered event
for event in filtered_events:
    url = event["url"]
    name = event["event_name"]
    confidence = event["confidence"]
    description = event.get("event_description", "")  # Ensure description is correctly extracted
    print(f"Processing event: {name} with confidence {confidence}")
    if confidence >= CONFIDENCE_THRESHOLD:
        # Ensure the correct description is passed
        send_event_notification(name, description, url)
